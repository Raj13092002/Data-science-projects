# %%
import tensorflow as tf
from tensorflow.keras import datasets,layers,models

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
#import the data of CIFAR-10

# %%
datasets.cifar10.load_data()
# Out:
# ((array([[[[ 59,  62,  63],
#            [ 43,  46,  45],
#            [ 50,  48,  43],
#            ...,
#            [158, 132, 108],
#            [152, 125, 102],
#            [148, 124, 103]],
#
#           [[ 16,  20,  20],
#            [  0,   0,   0],
#            [ 18,   8,   0],
#            ...,
#            [123,  88,  55],
#            [119,  83,  50],
#            [122,  87,  57]],
#
#           [[ 25,  24,  21],
#            [ 16,   7,   0],
#            [ 49,  27,   8],
#            ...,
#            [118,  84,  50],
#            [120,  84,  50],
#            [109,  73,  42]],
#
#           ...,
#
#           [[208, 170,  96],
#            [201, 153,  34],
#            [198, 161,  26],
#            ...,
#            [160, 133,  70],
#            [ 56,  31,   7],
#            [ 53,  34,  20]],
#
#           [[180, 139,  96],
#            [173, 123,  42],
#            [186, 144,  30],
#            ...,
#            [184, 148,  94],
#            [ 97,  62,  34],
# ...

# %%
#SPLIT THE DATA for training and testing the data

# %%
(train_x,train_y),(test_x,test_y)=datasets.cifar10.load_data()

# %%
train_x.shape
# Out:
# (50000, 32, 32, 3)

# %%
train_x
# Out:
# array([[[[ 59,  62,  63],
#          [ 43,  46,  45],
#          [ 50,  48,  43],
#          ...,
#          [158, 132, 108],
#          [152, 125, 102],
#          [148, 124, 103]],
#
#         [[ 16,  20,  20],
#          [  0,   0,   0],
#          [ 18,   8,   0],
#          ...,
#          [123,  88,  55],
#          [119,  83,  50],
#          [122,  87,  57]],
#
#         [[ 25,  24,  21],
#          [ 16,   7,   0],
#          [ 49,  27,   8],
#          ...,
#          [118,  84,  50],
#          [120,  84,  50],
#          [109,  73,  42]],
#
#         ...,
#
#         [[208, 170,  96],
#          [201, 153,  34],
#          [198, 161,  26],
#          ...,
#          [160, 133,  70],
#          [ 56,  31,   7],
#          [ 53,  34,  20]],
#
#         [[180, 139,  96],
#          [173, 123,  42],
#          [186, 144,  30],
#          ...,
#          [184, 148,  94],
#          [ 97,  62,  34],
#          [ 83,  53,  34]],
#
#         [[177, 144, 116],
# ...

# %%
test_x.shape
# Out:
# (10000, 32, 32, 3)

# %%
train_y[:5]
# Out:
# array([[6],
#        [9],
#        [9],
#        [4],
#        [1]], dtype=uint8)

# %%
train_y.shape
# Out:
# (50000, 1)

# %%
#we have to reshape the y because y is in 2-d we have to do inm 1-d data

# %% [raw]
# # y_train is a 2D array, for our classification having 1D array is good enough. so we will convert this to now 1D array

# %%
train_y = train_y.reshape(-1,)
train_y[:5]
# Out:
# array([6, 9, 9, 4, 1], dtype=uint8)

# %%
#convert the 2-d to 1-d

# %%
test_y = test_y.reshape(-1,)
test_y
# Out:
# array([3, 8, 8, ..., 5, 1, 7], dtype=uint8)

# %%
#we have to label the x axis fdor this

# %%
classes = ["airplane","automobile","bird","cat","deer","dog","frog","horse","ship","truck"]

# %%
def plot_sample(x,y, index):
    plt.figure(figsize = (15,2))
    plt.imshow(x[index])
    plt.xlabel(classes[y[index]])

# %%
plot_sample(train_x,train_y,4)

# %%
train_x=train_x.reshape(50000,3072)

# %%
train_x.shape
# Out:
# (50000, 3072)

# %%
train_y
# Out:
# array([6, 9, 9, ..., 9, 1, 1], dtype=uint8)

# %%
from sklearn.linear_model import LogisticRegression

# %%
model=LogisticRegression()

# %%
model.fit(train_x,train_y)
# Out:
# c:\users\hp\appdata\local\programs\python\python39\lib\site-packages\sklearn\linear_model\_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
test_x=test_x.reshape(10000,3072)

# %%
model.score(test_x,test_y)
# Out:
# 0.4024

# %%
model.predict(test_x[:5])
# Out:
# array([3, 9, 8, 8, 4], dtype=uint8)

# %%
test_y[:5]
# Out:
# array([3, 8, 8, 0, 6], dtype=uint8)

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
model1=KNeighborsClassifier()

# %%
model1.fit(train_x,train_y)
# Out:
# KNeighborsClassifier()

# %%
model1.score(test_x,test_y)
# Out:
# 0.3398
